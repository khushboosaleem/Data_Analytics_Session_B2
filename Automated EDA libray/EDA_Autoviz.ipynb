# %%
# !pip install autoviz
# Out:
# Requirement already satisfied: autoviz in c:\users\faatiq_pc\anaconda3\lib\site-packages (0.1.905)
# Requirement already satisfied: xlrd in c:\users\faatiq_pc\anaconda3\lib\site-packages (from autoviz) (2.0.1)
# Requirement already satisfied: wordcloud in c:\users\faatiq_pc\anaconda3\lib\site-packages (from autoviz) (1.9.4)
# Requirement already satisfied: emoji in c:\users\faatiq_pc\anaconda3\lib\site-packages (from autoviz) (2.14.0)
# Requirement already satisfied: pyamg in c:\users\faatiq_pc\anaconda3\lib\site-packages (from autoviz) (5.2.1)
# Requirement already satisfied: scikit-learn in c:\users\faatiq_pc\anaconda3\lib\site-packages (from autoviz) (1.6.1)
# Requirement already satisfied: statsmodels in c:\users\faatiq_pc\anaconda3\lib\site-packages (from autoviz) (0.14.4)
# Requirement already satisfied: nltk in c:\users\faatiq_pc\anaconda3\lib\site-packages (from autoviz) (3.9.1)
# Requirement already satisfied: textblob in c:\users\faatiq_pc\anaconda3\lib\site-packages (from autoviz) (0.18.0.post0)
# Requirement already satisfied: xgboost<1.7,>=0.82 in c:\users\faatiq_pc\anaconda3\lib\site-packages (from autoviz) (1.6.2)
# Requirement already satisfied: fsspec>=0.8.3 in c:\users\faatiq_pc\anaconda3\lib\site-packages (from autoviz) (2025.3.2)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\faatiq_pc\anaconda3\lib\site-packages (from autoviz) (4.12.2)
# Requirement already satisfied: pandas-dq>=1.29 in c:\users\faatiq_pc\anaconda3\lib\site-packages (from autoviz) (1.29)
# Requirement already satisfied: numpy>=1.24.0 in c:\users\faatiq_pc\anaconda3\lib\site-packages (from autoviz) (1.26.4)
# Requirement already satisfied: hvplot>=0.9.2 in c:\users\faatiq_pc\anaconda3\lib\site-packages (from autoviz) (0.11.3)
# Requirement already satisfied: holoviews>=1.16.0 in c:\users\faatiq_pc\anaconda3\lib\site-packages (from autoviz) (1.20.2)
# Requirement already satisfied: panel>=1.4.0 in c:\users\faatiq_pc\anaconda3\lib\site-packages (from autoviz) (1.6.3)
# Requirement already satisfied: pandas>=2.0 in c:\users\faatiq_pc\anaconda3\lib\site-packages (from autoviz) (2.2.3)
# Requirement already satisfied: matplotlib>3.7.4 in c:\users\faatiq_pc\anaconda3\lib\site-packages (from autoviz) (3.9.4)
# Requirement already satisfied: seaborn>0.12.2 in c:\users\faatiq_pc\anaconda3\lib\site-packages (from autoviz) (0.13.2)
# Requirement already satisfied: scipy in c:\users\faatiq_pc\anaconda3\lib\site-packages (from xgboost<1.7,>=0.82->autoviz) (1.13.1)
# Requirement already satisfied: bokeh>=3.1 in c:\users\faatiq_pc\anaconda3\lib\site-packages (from holoviews>=1.16.0->autoviz) (3.6.2)
# Requirement already satisfied: colorcet in c:\users\faatiq_pc\anaconda3\lib\site-packages (from holoviews>=1.16.0->autoviz) (3.1.0)
# Requirement already satisfied: packaging in c:\users\faatiq_pc\anaconda3\lib\site-packages (from holoviews>=1.16.0->autoviz) (24.2)
# Requirement already satisfied: param<3.0,>=2.0 in c:\users\faatiq_pc\anaconda3\lib\site-packages (from holoviews>=1.16.0->autoviz) (2.2.0)
# Requirement already satisfied: pyviz-comms>=2.1 in c:\users\faatiq_pc\anaconda3\lib\site-packages (from holoviews>=1.16.0->autoviz) (3.0.2)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\faatiq_pc\anaconda3\lib\site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (3.1.6)
# Requirement already satisfied: contourpy>=1.2 in c:\users\faatiq_pc\anaconda3\lib\site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (1.3.1)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\faatiq_pc\anaconda3\lib\site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (11.1.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\faatiq_pc\anaconda3\lib\site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (6.0.2)
# Requirement already satisfied: tornado>=6.2 in c:\users\faatiq_pc\anaconda3\lib\site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (6.4.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\faatiq_pc\anaconda3\lib\site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\faatiq_pc\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh>=3.1->holoviews>=1.16.0->autoviz) (3.0.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\faatiq_pc\anaconda3\lib\site-packages (from matplotlib>3.7.4->autoviz) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\faatiq_pc\anaconda3\lib\site-packages (from matplotlib>3.7.4->autoviz) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\faatiq_pc\anaconda3\lib\site-packages (from matplotlib>3.7.4->autoviz) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\faatiq_pc\anaconda3\lib\site-packages (from matplotlib>3.7.4->autoviz) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\faatiq_pc\anaconda3\lib\site-packages (from matplotlib>3.7.4->autoviz) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\faatiq_pc\anaconda3\lib\site-packages (from pandas>=2.0->autoviz) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\faatiq_pc\anaconda3\lib\site-packages (from pandas>=2.0->autoviz) (2025.2)
# Requirement already satisfied: bleach in c:\users\faatiq_pc\anaconda3\lib\site-packages (from panel>=1.4.0->autoviz) (6.2.0)
# Requirement already satisfied: linkify-it-py in c:\users\faatiq_pc\anaconda3\lib\site-packages (from panel>=1.4.0->autoviz) (2.0.0)
# Requirement already satisfied: markdown in c:\users\faatiq_pc\anaconda3\lib\site-packages (from panel>=1.4.0->autoviz) (3.8)
# Requirement already satisfied: markdown-it-py in c:\users\faatiq_pc\anaconda3\lib\site-packages (from panel>=1.4.0->autoviz) (2.2.0)
# Requirement already satisfied: mdit-py-plugins in c:\users\faatiq_pc\anaconda3\lib\site-packages (from panel>=1.4.0->autoviz) (0.3.0)
# Requirement already satisfied: requests in c:\users\faatiq_pc\anaconda3\lib\site-packages (from panel>=1.4.0->autoviz) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\faatiq_pc\anaconda3\lib\site-packages (from panel>=1.4.0->autoviz) (4.67.1)
# Requirement already satisfied: six>=1.5 in c:\users\faatiq_pc\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>3.7.4->autoviz) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\faatiq_pc\anaconda3\lib\site-packages (from scikit-learn->autoviz) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\faatiq_pc\anaconda3\lib\site-packages (from scikit-learn->autoviz) (3.5.0)
# Requirement already satisfied: webencodings in c:\users\faatiq_pc\anaconda3\lib\site-packages (from bleach->panel>=1.4.0->autoviz) (0.5.1)
# Requirement already satisfied: uc-micro-py in c:\users\faatiq_pc\anaconda3\lib\site-packages (from linkify-it-py->panel>=1.4.0->autoviz) (1.0.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\faatiq_pc\anaconda3\lib\site-packages (from markdown-it-py->panel>=1.4.0->autoviz) (0.1.0)
# Requirement already satisfied: click in c:\users\faatiq_pc\anaconda3\lib\site-packages (from nltk->autoviz) (8.1.8)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\faatiq_pc\anaconda3\lib\site-packages (from nltk->autoviz) (2024.11.6)
# Requirement already satisfied: colorama in c:\users\faatiq_pc\anaconda3\lib\site-packages (from click->nltk->autoviz) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\faatiq_pc\anaconda3\lib\site-packages (from requests->panel>=1.4.0->autoviz) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\faatiq_pc\anaconda3\lib\site-packages (from requests->panel>=1.4.0->autoviz) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\faatiq_pc\anaconda3\lib\site-packages (from requests->panel>=1.4.0->autoviz) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\faatiq_pc\anaconda3\lib\site-packages (from requests->panel>=1.4.0->autoviz) (2025.4.26)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\faatiq_pc\anaconda3\lib\site-packages (from statsmodels->autoviz) (1.0.1)

# %%
import seaborn as sns

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
from autoviz.AutoViz_Class import AutoViz_Class
# Out:
# Imported v0.1.905. Please call AutoViz in this sequence:
#     AV = AutoViz_Class()
#     %matplotlib inline
#     dfte = AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
#                chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)

# %%
Av = AutoViz_Class()

# %%
Av

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

dft = Av.AutoViz(df)
# Out:
# Shape of your Data Set loaded: (244, 7)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  2
#     Number of Integer-Categorical Columns =  1
#     Number of String-Categorical Columns =  0
#     Number of Factor-Categorical Columns =  4
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  0
#     Number of Columns to Delete =  0
#     7 Predictors classified...
#         No variables removed since no ID or low-information variables found in data set
# To fix these data quality issues in the dataset, import FixDQ from autoviz...
# There are 1 duplicate rows in your dataset
#     Alert: Dropping duplicate rows can sometimes cause your column data types to change to object!
#     All variables classified into correct types.
# <style type="text/css">
# #T_c7499_row0_col0, #T_c7499_row0_col2, #T_c7499_row0_col3, #T_c7499_row0_col4, #T_c7499_row0_col5, #T_c7499_row1_col0, #T_c7499_row1_col2, #T_c7499_row1_col3, #T_c7499_row1_col4, #T_c7499_row1_col5, #T_c7499_row2_col0, #T_c7499_row2_col2, #T_c7499_row2_col3, #T_c7499_row2_col4, #T_c7499_row2_col5, #T_c7499_row3_col0, #T_c7499_row3_col2, #T_c7499_row3_col3, #T_c7499_row3_col4, #T_c7499_row3_col5, #T_c7499_row4_col0, #T_c7499_row4_col2, #T_c7499_row4_col3, #T_c7499_row4_col4, #T_c7499_row4_col5, #T_c7499_row5_col0, #T_c7499_row5_col2, #T_c7499_row5_col3, #T_c7499_row5_col4, #T_c7499_row5_col5, #T_c7499_row6_col0, #T_c7499_row6_col2, #T_c7499_row6_col3, #T_c7499_row6_col4, #T_c7499_row6_col5 {
#   font-family: Segoe UI;
# }
# #T_c7499_row0_col1, #T_c7499_row1_col1, #T_c7499_row2_col1, #T_c7499_row3_col1, #T_c7499_row4_col1, #T_c7499_row5_col1, #T_c7499_row6_col1 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_c7499">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7499_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_c7499_level0_col1" class="col_heading level0 col1" >Missing Values%</th>
#       <th id="T_c7499_level0_col2" class="col_heading level0 col2" >Unique Values%</th>
#       <th id="T_c7499_level0_col3" class="col_heading level0 col3" >Minimum Value</th>
#       <th id="T_c7499_level0_col4" class="col_heading level0 col4" >Maximum Value</th>
#       <th id="T_c7499_level0_col5" class="col_heading level0 col5" >DQ Issue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7499_level0_row0" class="row_heading level0 row0" >total_bill</th>
#       <td id="T_c7499_row0_col0" class="data row0 col0" >float64</td>
#       <td id="T_c7499_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_c7499_row0_col2" class="data row0 col2" >NA</td>
#       <td id="T_c7499_row0_col3" class="data row0 col3" >3.070000</td>
#       <td id="T_c7499_row0_col4" class="data row0 col4" >50.810000</td>
#       <td id="T_c7499_row0_col5" class="data row0 col5" >Column has 9 outliers greater than upper bound (40.37) or lower than lower bound(-2.81). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_c7499_level0_row1" class="row_heading level0 row1" >tip</th>
#       <td id="T_c7499_row1_col0" class="data row1 col0" >float64</td>
#       <td id="T_c7499_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_c7499_row1_col2" class="data row1 col2" >NA</td>
#       <td id="T_c7499_row1_col3" class="data row1 col3" >1.000000</td>
#       <td id="T_c7499_row1_col4" class="data row1 col4" >10.000000</td>
#       <td id="T_c7499_row1_col5" class="data row1 col5" >Column has 8 outliers greater than upper bound (5.94) or lower than lower bound(-0.36). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_c7499_level0_row2" class="row_heading level0 row2" >sex</th>
#       <td id="T_c7499_row2_col0" class="data row2 col0" >category</td>
#       <td id="T_c7499_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_c7499_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_c7499_row2_col3" class="data row2 col3" ></td>
#       <td id="T_c7499_row2_col4" class="data row2 col4" ></td>
#       <td id="T_c7499_row2_col5" class="data row2 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_c7499_level0_row3" class="row_heading level0 row3" >smoker</th>
#       <td id="T_c7499_row3_col0" class="data row3 col0" >category</td>
#       <td id="T_c7499_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_c7499_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_c7499_row3_col3" class="data row3 col3" ></td>
#       <td id="T_c7499_row3_col4" class="data row3 col4" ></td>
#       <td id="T_c7499_row3_col5" class="data row3 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_c7499_level0_row4" class="row_heading level0 row4" >day</th>
#       <td id="T_c7499_row4_col0" class="data row4 col0" >category</td>
#       <td id="T_c7499_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_c7499_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_c7499_row4_col3" class="data row4 col3" ></td>
#       <td id="T_c7499_row4_col4" class="data row4 col4" ></td>
#       <td id="T_c7499_row4_col5" class="data row4 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_c7499_level0_row5" class="row_heading level0 row5" >time</th>
#       <td id="T_c7499_row5_col0" class="data row5 col0" >category</td>
#       <td id="T_c7499_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_c7499_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_c7499_row5_col3" class="data row5 col3" ></td>
#       <td id="T_c7499_row5_col4" class="data row5 col4" ></td>
#       <td id="T_c7499_row5_col5" class="data row5 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_c7499_level0_row6" class="row_heading level0 row6" >size</th>
#       <td id="T_c7499_row6_col0" class="data row6 col0" >int64</td>
#       <td id="T_c7499_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_c7499_row6_col2" class="data row6 col2" >2</td>
#       <td id="T_c7499_row6_col3" class="data row6 col3" >1.000000</td>
#       <td id="T_c7499_row6_col4" class="data row6 col4" >6.000000</td>
#       <td id="T_c7499_row6_col5" class="data row6 col5" >Column has 9 outliers greater than upper bound (4.50) or lower than lower bound(0.50). Cap them or remove them.</td>
#     </tr>
#   </tbody>
# </table>
# Number of All Scatter Plots = 3
# All Plots done
# Time to run AutoViz = 5 seconds
#
#  ###################### AUTO VISUALIZATION Completed ########################
